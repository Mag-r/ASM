# %%
# Linalg support
import numpy as onp

# Jax imports
import jax
from jax import lax
from jax import jit, vmap, grad
import jax.numpy as np
from jax import random
from functools import partial

# ML imports
import optax

# Jax-md imports
from jax_md import energy, space, simulate, quantity, minimize

# Plotting.
import matplotlib.pyplot as plt

# Tracking
from rich.progress import track
import pickle
# Out:
# 2024-05-14 15:32:39.764669: W external/xla/xla/service/gpu/runtime/support.cc:58] Intercepted XLA runtime error:
# INTERNAL: jaxlib/gpu/solver_kernels.cc:45: operation gpusolverDnCreate(&handle) failed: cuSolver internal error
# 2024-05-14 15:32:39.764724: E external/xla/xla/pjrt/pjrt_stream_executor_client.cc:2732] Execution of replica 0 failed: INTERNAL: Failed to execute XLA Runtime executable: run time error: custom call 'xla.gpu.custom_call' failed: jaxlib/gpu/solver_kernels.cc:45: operation gpusolverDnCreate(&handle) failed: cuSolver internal error; current tracing scope: custom-call.12; current profiling annotation: XlaModule:#prefix=jit(eigh)/jit(main),hlo_module=jit_eigh,program_id=93#.
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[2], line 16
#      13 import optax
#      15 # Jax-md imports
# ---> 16 from jax_md import energy, space, simulate, quantity, minimize
#      18 # Plotting.
#      19 import matplotlib.pyplot as plt
#
# File ~/conda/envs/mlpes/lib/python3.10/site-packages/jax_md/__init__.py:27
#      25 from jax_md import util
#      26 from jax_md import io
# ---> 27 from jax_md import rigid_body
#      29 try:
#      30   # Attempt to load colab_tools if IPython is installed.
#      31   from jax_md import colab_tools
#
# File ~/conda/envs/mlpes/lib/python3.10/site-packages/jax_md/rigid_body.py:1021
#    1016 square = point_union_shape(
#    1017     onp.array([[-0.5, -0.5], [0.5, -0.5], [0.5, 0.5], [-0.5, 0.5]], f32),
#    1018     f32(1.0))
#    1020 # 3D Shapes.
# -> 1021 tetrahedron = point_union_shape(
#    1022   onp.array([[1.0, 1.0, 1.0],
#    1023              [ 1.0, -1.0, -1.0],
#    1024              [-1.0,  1.0, -1.0],
#    1025              [-1.0, -1.0, 1.0]], f32) * f32(0.5),
#    1026     f32(1.0))
#    1027 octohedron = point_union_shape(
#    1028   onp.array([[1.0, 0.0, 0.0],
#    1029              [-1.0, 0.0, 0.0],
#    (...)
#    1033              [0.0, 0.0, -1.0]], f32) * f32(0.5),
#    1034     f32(1.0))
#
# File ~/conda/envs/mlpes/lib/python3.10/site-packages/jax_md/rigid_body.py:828, in point_union_shape(points, masses)
#     823   masses = masses * jnp.ones((len(points),), points.dtype)
#     824 shape = RigidPointUnion(points=points,
#     825                         masses=masses,
#     826                         point_count=jnp.array([len(points)]),
#     827                         point_offset=jnp.array([0]))
# --> 828 return _transform_to_diagonal_frame(shape)
#
# File ~/conda/envs/mlpes/lib/python3.10/site-packages/jax_md/rigid_body.py:797, in _transform_to_diagonal_frame(shape)
#     794 total_mass = jnp.sum(shape.masses)
#     795 I, = shape.moment_of_inertia()
# --> 797 I_diag, U = jnp.linalg.eigh(I)
#     799 points = jnp.einsum('ni,ij->nj', shape.points, U)
#     800 return RigidPointUnion(points,
#     801                       shape.masses,
#     802                       shape.point_count,
#     803                       shape.point_offset)
#
#     [... skipping hidden 10 frame]
#
# File ~/conda/envs/mlpes/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:1159, in ExecuteReplicated.__call__(self, *args)
#    1157   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1158 else:
# -> 1159   results = self.xla_executable.execute_sharded(input_bufs)
#    1160 if dispatch.needs_check_special():
#    1161   out_arrays = results.disassemble_into_single_device_arrays()
#
# XlaRuntimeError: INTERNAL: Failed to execute XLA Runtime executable: run time error: custom call 'xla.gpu.custom_call' failed: jaxlib/gpu/solver_kernels.cc:45: operation gpusolverDnCreate(&handle) failed: cuSolver internal error; current tracing scope: custom-call.12; current profiling annotation: XlaModule:#prefix=jit(eigh)/jit(main),hlo_module=jit_eigh,program_id=93#.

# %%
# Load the model params for one functional

xc="pbe"

params = None
with open(f"params_{xc}.pkl", "rb") as f:
    params = pickle.load(f)
n_particles = [100, 1000,]  # Scale to required sizes
time_step = 0.01
n_steps = 10000  # Scale up for better statistics

# %%
def run_md(model_params, n_particles: int, temperature, time_step, n_steps):
    """
    Run molecular dynamics simulation.
    """
    # Parameters to correctly instantiate the simulation box.
    rho_argon = 1.40  # g/cm³
    mass_argon = 39.95  # g/mol
    avogadro = 6.022e23  # atoms/mol
    kb = 8.617e-5  # Boltzmann constant

    # Calculate number density in atoms/cm³
    n_argon = (rho_argon * avogadro) / mass_argon

    # Continuing from the previous calculation
    n_argon_cm3 = n_argon  # This is in atoms/cm³

    # Conversion factor from cm³ to Å³
    conversion_factor = 1e24  # (10^8)^3

    # Convert number density to atoms/Å³ for use in simulations
    n_argon_A3 = n_argon_cm3 / conversion_factor

    # Get the initial conditions of the simulation
    n_particles = 64  # Increase this to the required number of particles
    dimension = 3

    # Compute the box size
    box_size = quantity.box_size_at_number_density(n_particles, n_argon_A3, dimension)

    # Get displacement function
    displacement, shift = space.periodic(box_size)

    # Set initial positions of particles.
    key = random.PRNGKey(0)
    initial_positions = random.uniform(
        key, (n_particles, dimension), minval=0.0, maxval=box_size, dtype=np.float64
    )

    # Define a random graph neural network. This must be changed for the BP network.
    neighbor_fn, init_fn, energy_fn = energy.graph_network_neighbor_list(
        displacement, box_size, r_cutoff=4.0, dr_threshold=0.0, n_recurrences=2, mlp_sizes=(12, 12))

    # Neighbour list computation, should improve performance.
    neighbor = neighbor_fn.allocate(initial_positions, extra_capacity=6)

    print('Allocating space for at most {} edges'.format(neighbor.idx.shape[1]))

    baked_e_function = partial(energy_fn, model_params)

    # Energy minimization

    # Prepare the FIRE minimization
    fire_init, fire_apply = minimize.fire_descent(baked_e_function, shift)
    fire_apply = jit(fire_apply)
    fire_state = fire_init(initial_positions)

    # Perform the minimization
    minimisation_energy = []

    @jit
    def fire_sim(state, nbrs):
        def step(i, state_nbrs):
            state, nbrs = state_nbrs
            nbrs = nbrs.update(state.position)
            return fire_apply(state, neighbor=nbrs), nbrs
        return lax.fori_loop(0, 25, step, (state, nbrs))

    # Adjust the minimisation steps until it converges
    for i in range(1000):
        fire_state, neighbor = fire_sim(fire_state, neighbor)
        minimisation_energy += [baked_e_function(fire_state.position)]

    # Run the simulation

    init_fn, apply_fn = simulate.nve(baked_e_function, shift, time_step)
    state = init_fn(key, fire_state.position, kT = kb * temperature)

    # Add your analysis code from the previous exercise here.
    def compute_potential_energy(state):
        """
        Compute the potential energy of the system.

        Parameters
        ----------
        state 
            The current state of the simulation.
        """
        # Implement the function
        potential_energy=energy_fn(state.position)
        return potential_energy

    def compute_kinetic_energy(state):
        """
        Compute the kinetic energy of the system.

        Parameters
        ----------
        state 
            The current state of the simulation.
        """
        # Implement the function
        kinetic_energy = quantity.kinetic_energy(momentum=state.momentum)
        return kinetic_energy
    
    @jit
    def prod_sim(state, nbrs):
        def step(i, state_nbrs):
            state, nbrs = state_nbrs
            nbrs = nbrs.update(state.position)
            return apply_fn(state, neighbor=nbrs), nbrs
        return lax.fori_loop(0, 25, step, (state, nbrs))
    

    potential_energy = []
    kinetic_energy = []
    trajectory = []
    for step in track(range(n_steps)):
        state, neighbor = apply_fn(state, neighbor)  # Update the state
        
        # Record at certain intervals
        if step % 50 == 0:
            # Compute the potential and kinetic energy
            potential_energy.append(compute_potential_energy(state))
            kinetic_energy.append(compute_kinetic_energy(state))

            # Add some trajectory recording here
            trajectory.append(state.position)

    return trajectory, potential_energy, kinetic_energy

# %%
# Run the simulations

# Compute RDFS

# Plot the results

np.save(f'trajectory_{xc}.npy', trajectory)
